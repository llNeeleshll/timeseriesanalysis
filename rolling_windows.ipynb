# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame(np.random.randn(600, 3), index = pd.date_range('5/1/2016', freq = 'D', periods = 600), columns = ['A', 'B', 'C'])

# %%
df.head()
# Out:
#                    A         B         C
# 2016-05-01 -0.824120  0.171643  0.619816
# 2016-05-02  0.792734 -0.656388 -0.732077
# 2016-05-03 -0.737949 -0.426394  0.312953
# 2016-05-04 -0.090764  0.246216  1.501674
# 2016-05-05 -0.356074 -0.896844  1.877021

# %%
df.plot()
# Out:
# <AxesSubplot:>
